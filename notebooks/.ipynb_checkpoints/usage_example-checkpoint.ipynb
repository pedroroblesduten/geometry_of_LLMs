# %%
import os
import sys



module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)


from llm_module import ModelLLM
from IPython.display import display

# %%
# Example usage
model_llm = ModelLLM("meta-llama/Llama-2-7b-chat-hf", "./results/", device='cuda')
input_text = "Complete o texto a seguir: tenho por dom a paixao, nas queimadas de tronco seco"
text = model_llm.generate_text(input_text)
display(text)
input_embeddings = model_llm.get_embeddings_from_input(input_text)
display(input_embeddings.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Example usage
# ----> 2 model_llm = ModelLLM("meta-llama/Llama-2-7b-chat-hf", "./results/", device='cuda')
#       3 input_text = "Complete o texto a seguir: tenho por dom a paixao, nas queimadas de tronco seco"
#       4 text = model_llm.generate_text(input_text)
#
# File /home_cerberus/speed/henriquehott/llama2-exploring/llm_module/model_llm.py:20, in ModelLLM.__init__(self, model_name_or_path, results_path, device, torch_dtype)
#      18 self.model_name_or_path = model_name_or_path
#      19 self.results_path = results_path
# ---> 20 self.__load_checkpoint()
#
# File /home_cerberus/speed/henriquehott/llama2-exploring/llm_module/model_llm.py:25, in ModelLLM.__load_checkpoint(self)
#      24 def __load_checkpoint(self) -> None:
# ---> 25     self.tokenizer = AutoTokenizer.from_pretrained(self.model_name_or_path)
#      26     self.model = AutoModelForCausalLM.from_pretrained(
#      27         self.model_name_or_path,
#      28         device_map=self.device,
#      29         torch_dtype=self.torch_dtype
#      30     )
#      32     self.model.eval()
#
# File ~/miniconda3/envs/modelo-produto/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:471, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     468     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     470 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# --> 471 tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#     472 config_tokenizer_class = tokenizer_config.get("tokenizer_class")
#     473 tokenizer_auto_map = None
#
# File ~/miniconda3/envs/modelo-produto/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:332, in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, **kwargs)
#     263 def get_tokenizer_config(
#     264     pretrained_model_name_or_path: Union[str, os.PathLike],
#     265     cache_dir: Optional[Union[str, os.PathLike]] = None,
#    (...)
#     272     **kwargs,
#     273 ):
#     274     """
#     275     Loads the tokenizer configuration from a pretrained model tokenizer configuration.
#     276
#    (...)
#     330     tokenizer_config = get_tokenizer_config("tokenizer-test")
#     331     ```"""
# --> 332     resolved_config_file = get_file_from_repo(
#     333         pretrained_model_name_or_path,
#     334         TOKENIZER_CONFIG_FILE,
#     335         cache_dir=cache_dir,
#     336         force_download=force_download,
#     337         resume_download=resume_download,
#     338         proxies=proxies,
#     339         use_auth_token=use_auth_token,
#     340         revision=revision,
#     341         local_files_only=local_files_only,
#     342     )
#     343     if resolved_config_file is None:
#     344         logger.info("Could not locate the tokenizer configuration file, will try to use the model config instead.")
#
# File ~/miniconda3/envs/modelo-produto/lib/python3.10/site-packages/transformers/utils/hub.py:678, in get_file_from_repo(path_or_repo, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only)
#     674     resolved_file = hf_bucket_url(path_or_repo, filename=filename, revision=revision, mirror=None)
#     676 try:
#     677     # Load from URL or cache if already cached
# --> 678     resolved_file = cached_path(
#     679         resolved_file,
#     680         cache_dir=cache_dir,
#     681         force_download=force_download,
#     682         proxies=proxies,
#     683         resume_download=resume_download,
#     684         local_files_only=local_files_only,
#     685         use_auth_token=use_auth_token,
#     686     )
#     688 except RepositoryNotFoundError:
#     689     raise EnvironmentError(
#     690         f"{path_or_repo} is not a local folder and is not a valid model identifier "
#     691         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to "
#     692         "pass a token having permission to this repo with `use_auth_token` or log in with "
#     693         "`huggingface-cli login` and pass `use_auth_token=True`."
#     694     )
#
# File ~/miniconda3/envs/modelo-produto/lib/python3.10/site-packages/transformers/utils/hub.py:282, in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#     278     local_files_only = True
#     280 if is_remote_url(url_or_filename):
#     281     # URL, so get it from the cache (downloading if necessary)
# --> 282     output_path = get_from_cache(
#     283         url_or_filename,
#     284         cache_dir=cache_dir,
#     285         force_download=force_download,
#     286         proxies=proxies,
#     287         resume_download=resume_download,
#     288         user_agent=user_agent,
#     289         use_auth_token=use_auth_token,
#     290         local_files_only=local_files_only,
#     291     )
#     292 elif os.path.exists(url_or_filename):
#     293     # File, and it exists.
#     294     output_path = url_or_filename
#
# File ~/miniconda3/envs/modelo-produto/lib/python3.10/site-packages/transformers/utils/hub.py:545, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#     539                 raise FileNotFoundError(
#     540                     "Cannot find the requested files in the cached path and outgoing traffic has been"
#     541                     " disabled. To enable model look-ups and downloads online, set 'local_files_only'"
#     542                     " to False."
#     543                 )
#     544             else:
# --> 545                 raise ValueError(
#     546                     "Connection error, and we cannot find the requested files in the cached path."
#     547                     " Please try again or make sure your Internet connection is on."
#     548                 )
#     550 # From now on, etag is not None.
#     551 if os.path.exists(cache_path) and not force_download:
#
# ValueError: Connection error, and we cannot find the requested files in the cached path. Please try again or make sure your Internet connection is on.
